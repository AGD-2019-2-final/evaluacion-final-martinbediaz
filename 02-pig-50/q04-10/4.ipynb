# %%
import pandas as pd
df = pd.read_csv('truck_event_text_partition.csv', header=None)
#pd.from_csv("data.tsv", sep="\t")
#df_csv = pd.read_csv('data.csv', error_bad_lines=False, header=None)
df.head()
# Out:
#    0    1        2       3      4      5                           6   \
# 0  14   25  59:21.4  Normal -94.58  37.03   14|25|9223370572464814373
# 1  18   16  59:21.7  Normal -89.66  39.78   18|16|9223370572464814089
# 2  27  105  59:21.7  Normal -90.21  38.65  27|105|9223370572464814070
# 3  11   74  59:21.7  Normal -90.20  38.65   11|74|9223370572464814123
# 4  22   87  59:21.7  Normal -90.04  35.19   22|87|9223370572464814101
#
#              7                8           9   \
# 0  3.660000e+18       Adis Cesir   160405074
# 1  3.660000e+18        Grant Liu  1565885487
# 2  3.660000e+18  Mark Lochbihler  1325562373
# 3  3.660000e+18   Jamie Engesser  1567254452
# 4  3.660000e+18    Nadeem Asghar  1198242881
#
#                                        10             11
# 0           Joplin to Kansas City Route 2  2016-05-27-22
# 1           Springfield to KC Via Hanibal  2016-05-27-22
# 2  Springfield to KC Via Columbia Route 2  2016-05-27-22
# ...

# %%
# %load_ext bigdata

# %%
# %timeout 300

# %%
# %pig_start

# %%
# %%pig
# fs -rm truck_event_text_partition.csv
# fs -put truck_event_text_partition.csv .
# fs -rm output/*
# fs -rmdir  output
#
# u = LOAD 'truck_event_text_partition.csv' USING PigStorage(',')
# AS (driverId: INT, truckId: INT, eventTime: CHARARRAY, eventType: CHARARRAY, longitude: DOUBLE, latitude: DOUBLE,
#     eventKey: CHARARRAY, correlationId: CHARARRAY, driverName: CHARARRAY, routeId: INT, routeName: CHARARRAY,
#     eventDate: CHARARRAY);
# x = LIMIT u 10;
# y = FOREACH x GENERATE $0, $1, $2;
# z = ORDER y BY $0, $1,$2;
# --STORE z INTO 'output' USING PigStorage(',');
# --fs -get output/ .
# DUMP z;
# Out:
#  fs -rm truck_event_text_partition.csv
# rm: `truck_event_text_partition.csv': No such file or directory
#  fs -put truck_event_text_partition.csv .
#  fs -rm output/*
# Deleted output/_SUCCESS
# Deleted output/part-r-00000
#  fs -rmdir  output
#  u = LOAD 'truck_event_text_partition.csv' USING PigStorage(',')
# longitude: DOUBLE, latitude: DOUBLE,ntTime: CHARARRAY, eventType: CHARARRAY,
# teId: INT, routeName: CHARARRAY, ionId: CHARARRAY, driverName: CHARARRAY, rou
#     eventDate: CHARARRAY);
#  x = LIMIT u 10;
#  y = FOREACH x GENERATE $0, $1, $2;
#  z = ORDER y BY $0, $1,$2;
#  --STORE z INTO 'output' USING PigStorage(',');
#  --fs -get output/ .
#  DUMP z;
# 2020-02-15 05:29:11,258 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# ...

# %%
# !cat output/part-r-00000

# %%
# !hadoop fs -rm output/*
# !hadoop fs -rmdir  output
# !rmdir output
# Out:
# Deleted output/_SUCCESS
# Deleted output/part-r-00000

# %%
# %pig_quit

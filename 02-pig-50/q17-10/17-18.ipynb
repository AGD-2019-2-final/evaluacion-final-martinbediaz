# %%
# %load_ext bigdata

# %%
# %timeout 300

# %%
# %pig_start

# %%
# %%pig
# fs -rm output/*
# fs -rmdir  output
# fs -rm data.csv
# fs -put data.csv .
# u = LOAD 'data.csv' USING PigStorage(',')
#     AS (id:int,
#         firstname:CHARARRAY,
#         surname:CHARARRAY,
#         birthday:CHARARRAY,
#         color:CHARARRAY,
#         quantity:INT);
# A = FOREACH u GENERATE id, firstname, color, COUNT(DIFF(color, 'blue'));
# B = FOREACH A GENERATE $0, $1, $2, ($3 > 0 ? '1' : '0' );
# C = FILTER B BY $3 MATCHES '1';
# D = FOREACH C GENERATE $0, $1, $2, COUNT(DIFF(color, 'black'));
# E = FOREACH D GENERATE $0, $1, $2, ($3 > 0 ? '1' : '0' );
# F = FILTER E BY $3 MATCHES '1';
# G = FOREACH F GENERATE $1, $2;
# STORE G INTO 'output' USING PigStorage(',');
# DUMP G;
#
# --A = FILTER u BY color MATCHES 'blue';
# --E = UNION B, D;
# --F = ORDER E BY $0 ASC;
# --G = FOREACH F GENERATE $1, $2;
# --grouped = GROUP G BY ($1,$2);
# --keycount = FOREACH grouped GENERATE group, COUNT(G);
# --n = FOREACH keycount GENERATE FLATTEN($0);
#
# --C = FOREACH u GENERATE id, firstname, color, SUBSTRING(firstname, 0, 1);
# --D = FILTER C BY $3 MATCHES 'K';
# --E = FOREACH D GENERATE $0, $1, $2;
#
# --C = FOREACH B GENERATE $0, ($1 > 0 ? '1' : '2' );
# --A = FOREACH u GENERATE color,COUNT(DIFF($1, 'b')), id;
# --A = FOREACH u GENERATE $2, FLATTEN(STRSPLIT($2,''));
# --B = FOREACH A GENERATE $0, COUNT(TOBAG($1..));
# --C = ORDER B BY $0 DESC;
# --D = ORDER C BY $1 DESC;
# --E= LIMIT D 5;
# --u = LOAD 'data.csv' USING PigStorage(',');
# --AS (f1:chararray, f2:BAG{t: TUPLE()}, f3:MAP[]);
# --B = FOREACH A GENERATE $0, $1;
# --grouped = GROUP B BY ($0, $1);
# --D = FOREACH grouped GENERATE group, COUNT(B);
# --USING PigStorage('\t')
# --A = FOREACH u GENERATE f1, COUNT(f2), f3#'aaa', f3#'bbb', f3#'ccc', f3#'ddd', f3#'eee', f3#'fff',f3#'ggg',f3#'hhh',f3#'iii', f3#'jjj';
# --B = FOREACH A GENERATE $0, $1, COUNT(TOBAG($2..));
# --C = ORDER B BY $0, $1, $2;
# --A = LOAD "input" USING PigStorage(",") AS(f1:int,f2:chararray);;
# --B = FOREACH A GENERATE f1, FLATTEN(STRSPLIT(f2,"_"));
# --C = FOREACH B GENERATE $0,COUNT(TOBAG($1..));
# --grouped = GROUP u BY $1;
# --x = FOREACH u GENERATE COUNT(TOKENIZE($1));
# --y = FOREACH u GENERATE $0, FLATTEN(TOKENIZE(REPLACE($1,'{', ' ')));
# --grouped = GROUP x BY $0;
# --keycount = FOREACH grouped GENERATE group, COUNT(x);
# Out:
#  fs -rm output/*
# rm: `output/*': No such file or directory
#  fs -rmdir  output
# rmdir: `output': No such file or directory
#  fs -rm data.csv
# Deleted data.csv
#  fs -put data.csv .
#  u = LOAD 'data.csv' USING PigStorage(',')
#     AS (id:int,
#         firstname:CHARARRAY,
#         surname:CHARARRAY,
#         birthday:CHARARRAY,
#         color:CHARARRAY,
#         quantity:INT);
#  A = FOREACH u GENERATE id, firstname, color, COUNT(DIFF(color, 'blue'));
#  B = FOREACH A GENERATE $0, $1, $2, ($3 > 0 ? '1' : '0' );
#  C = FILTER B BY $3 MATCHES '1';
#  D = FOREACH C GENERATE $0, $1, $2, COUNT(DIFF(color, 'black'));
#  E = FOREACH D GENERATE $0, $1, $2, ($3 > 0 ? '1' : '0' );
#  F = FILTER E BY $3 MATCHES '1';
#  G = FOREACH F GENERATE $1, $2;
#  DUMP G;
# 2020-02-16 04:21:08,359 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-02-16 04:21:09,839 [JobControl] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-02-16 04:21:09,866 [JobControl] WARN  org.apache.hadoop.mapreduce.JobResourceUploader - No job jar file set.  User classes may not be found. See Job or Job#setJar(String).
# 2020-02-16 04:21:09,906 [JobControl] INFO  org.apache.hadoop.mapreduce.lib.input.FileInputFormat - Total input files to process : 1
# 2020-02-16 04:21:09,962 [JobControl] INFO  org.apache.hadoop.mapreduce.JobSubmitter - number of splits:1
# 2020-02-16 04:21:10,424 [JobControl] INFO  org.apache.hadoop.mapreduce.JobSubmitter - Submitting tokens for job: job_1581824406475_0005
# 2020-02-16 04:21:10,438 [JobControl] INFO  org.apache.hadoop.mapred.YARNRunner - Job jar is not present. Not adding any jar to the list of resources.
# 2020-02-16 04:21:10,726 [JobControl] INFO  org.apache.hadoop.yarn.client.api.impl.YarnClientImpl - Submitted application application_1581824406475_0005
# 2020-02-16 04:21:10,741 [JobControl] INFO  org.apache.hadoop.mapreduce.Job - The url to track the job: http://e052e21dffaf:8088/proxy/application_1581824406475_0005/
# 2020-02-16 04:21:36,002 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-02-16 04:21:36,037 [main] INFO  org.apache.hadoop.mapred.ClientServiceDelegate - Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 2020-02-16 04:21:36,170 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-02-16 04:21:36,179 [main] INFO  org.apache.hadoop.mapred.ClientServiceDelegate - Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 2020-02-16 04:21:36,219 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-02-16 04:21:36,225 [main] INFO  org.apache.hadoop.mapred.ClientServiceDelegate - Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 2020-02-16 04:21:36,284 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-02-16 04:21:36,290 [main] INFO  org.apache.hadoop.mapred.ClientServiceDelegate - Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 2020-02-16 04:21:36,336 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-02-16 04:21:36,342 [main] INFO  org.apache.hadoop.mapred.ClientServiceDelegate - Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 2020-02-16 04:21:36,382 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-02-16 04:21:36,387 [main] INFO  org.apache.hadoop.mapred.ClientServiceDelegate - Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 2020-02-16 04:21:36,455 [main] INFO  org.apache.hadoop.mapreduce.lib.input.FileInputFormat - Total input files to process : 1
# (Vivian,green)
# (Karen,green)
# (Cody,orange)
# (Gretchen,viole)
# (Karyn,red)
# (Merritt,indigo)
# (Jordan,indigo)
# (Hope,green)
# (Vivian,gray)
# (Clio,red)
# (Ayanna,orange)
# (Chanda,green)
# (Chadwick,yellow)
#  --A = FILTER u BY color MATCHES 'blue';
#  --E = UNION B, D;
#  --F = ORDER E BY $0 ASC;
#  --G = FOREACH F GENERATE $1, $2;
#  --STORE n INTO 'output' USING PigStorage(',');
#  --grouped = GROUP G BY ($1,$2);
#  --keycount = FOREACH grouped GENERATE group, COUNT(G);
#  --n = FOREACH keycount GENERATE FLATTEN($0);
# ;--C = FOREACH u GENERATE id, firstname, color, SUBSTRING(firstname, 0, 1)
#  --D = FILTER C BY $3 MATCHES 'K';
#  --E = FOREACH D GENERATE $0, $1, $2;
#  --C = FOREACH B GENERATE $0, ($1 > 0 ? '1' : '2' );
#  --A = FOREACH u GENERATE color,COUNT(DIFF($1, 'b')), id;
#  --A = FOREACH u GENERATE $2, FLATTEN(STRSPLIT($2,''));
#  --B = FOREACH A GENERATE $0, COUNT(TOBAG($1..));
#  --C = ORDER B BY $0 DESC;
#  --D = ORDER C BY $1 DESC;
#  --E= LIMIT D 5;
#  --u = LOAD 'data.csv' USING PigStorage(',');
#  --AS (f1:chararray, f2:BAG{t: TUPLE()}, f3:MAP[]);
#  --B = FOREACH A GENERATE $0, $1;
#  --grouped = GROUP B BY ($0, $1);
#  --D = FOREACH grouped GENERATE group, COUNT(B);
#  --USING PigStorage('\t')
# 'ddd', f3#'eee', f3#'fff',f3#'ggg',f3#'hhh',f3#'iii', f3#'jjj';#'ccc', f3#
#  --B = FOREACH A GENERATE $0, $1, COUNT(TOBAG($2..));
#  --C = ORDER B BY $0, $1, $2;
#  --A = LOAD "input" USING PigStorage(",") AS(f1:int,f2:chararray);;
#  --B = FOREACH A GENERATE f1, FLATTEN(STRSPLIT(f2,"_"));
#  --C = FOREACH B GENERATE $0,COUNT(TOBAG($1..));
#  --grouped = GROUP u BY $1;
#  --x = FOREACH u GENERATE COUNT(TOKENIZE($1));
#  --y = FOREACH u GENERATE $0, FLATTEN(TOKENIZE(REPLACE($1,'{', ' ')));
#  --grouped = GROUP x BY $0;
#  --keycount = FOREACH grouped GENERATE group, COUNT(x);

# %%
# %pig_quit

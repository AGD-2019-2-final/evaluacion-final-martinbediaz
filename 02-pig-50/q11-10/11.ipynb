# %%
# %load_ext bigdata

# %%
# %timeout 300

# %%
# %pig_start

# %%
# %%pig
# fs -rm output/*
# fs -rmdir  output
# fs -rm data.csv
# fs -put data.csv .
# u = LOAD 'data.csv' USING PigStorage(',')
#     AS (id:int,
#         firstname:CHARARRAY,
#         surname:CHARARRAY,
#         birthday:CHARARRAY,
#         color:CHARARRAY,
#         quantity:INT);
# A = FOREACH u GENERATE $2, UPPER($2), LOWER($2);
# B = ORDER A BY $0 ASC;
# --STORE A INTO 'output' USING PigStorage(',');
# DUMP B;
#
# --A = FOREACH u GENERATE $2, FLATTEN(STRSPLIT($2,''));
# --B = FOREACH A GENERATE $0, COUNT(TOBAG($1..));
# --C = ORDER B BY $0 DESC;
# --D = ORDER C BY $1 DESC;
# --E= LIMIT D 5;
#
# --u = LOAD 'data.csv' USING PigStorage(',');
# --AS (f1:chararray, f2:BAG{t: TUPLE()}, f3:MAP[]);
# --B = FOREACH A GENERATE $0, $1;
# --grouped = GROUP B BY ($0, $1);
# --D = FOREACH grouped GENERATE group, COUNT(B);
# --USING PigStorage('\t')
# --A = FOREACH u GENERATE f1, COUNT(f2), f3#'aaa', f3#'bbb', f3#'ccc', f3#'ddd', f3#'eee', f3#'fff',f3#'ggg',f3#'hhh',f3#'iii', f3#'jjj';
# --B = FOREACH A GENERATE $0, $1, COUNT(TOBAG($2..));
# --C = ORDER B BY $0, $1, $2;
# --A = LOAD "input" USING PigStorage(",") AS(f1:int,f2:chararray);;
# --B = FOREACH A GENERATE f1, FLATTEN(STRSPLIT(f2,"_"));
# --C = FOREACH B GENERATE $0,COUNT(TOBAG($1..));
# --grouped = GROUP u BY $1;
# --x = FOREACH u GENERATE COUNT(TOKENIZE($1));
# --y = FOREACH u GENERATE $0, FLATTEN(TOKENIZE(REPLACE($1,'{', ' ')));
# --grouped = GROUP x BY $0;
# --keycount = FOREACH grouped GENERATE group, COUNT(x);
# Out:
#  fs -rm output/*
# rm: `output/*': No such file or directory
#  fs -rmdir  output
# rmdir: `output': No such file or directory
#  fs -rm data.csv
# Deleted data.csv
#  fs -put data.csv .
#  u = LOAD 'data.csv' USING PigStorage(',')
#     AS (id:int,
#         firstname:CHARARRAY,
#         surname:CHARARRAY,
#         birthday:CHARARRAY,
#         color:CHARARRAY,
#         quantity:INT);
#  A = FOREACH u GENERATE $2, UPPER($2), LOWER($2);
#  B = ORDER A BY $0 ASC;
#  DUMP B;
# 2020-02-15 22:07:51,200 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-02-15 22:07:51,944 [JobControl] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-02-15 22:07:51,991 [JobControl] WARN  org.apache.hadoop.mapreduce.JobResourceUploader - No job jar file set.  User classes may not be found. See Job or Job#setJar(String).
# 2020-02-15 22:07:52,034 [JobControl] INFO  org.apache.hadoop.mapreduce.lib.input.FileInputFormat - Total input files to process : 1
# 2020-02-15 22:07:52,949 [JobControl] INFO  org.apache.hadoop.mapreduce.JobSubmitter - number of splits:1
# 2020-02-15 22:07:53,466 [JobControl] INFO  org.apache.hadoop.mapreduce.JobSubmitter - Submitting tokens for job: job_1581803984332_0002
# 2020-02-15 22:07:53,485 [JobControl] INFO  org.apache.hadoop.mapred.YARNRunner - Job jar is not present. Not adding any jar to the list of resources.
# 2020-02-15 22:07:53,622 [JobControl] INFO  org.apache.hadoop.yarn.client.api.impl.YarnClientImpl - Submitted application application_1581803984332_0002
# 2020-02-15 22:07:53,637 [JobControl] INFO  org.apache.hadoop.mapreduce.Job - The url to track the job: http://72a54844fdeb:8088/proxy/application_1581803984332_0002/
# 2020-02-15 22:08:18,960 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-02-15 22:08:18,974 [main] INFO  org.apache.hadoop.mapred.ClientServiceDelegate - Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 2020-02-15 22:08:19,294 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-02-15 22:08:19,305 [main] INFO  org.apache.hadoop.mapred.ClientServiceDelegate - Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 2020-02-15 22:08:19,386 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-02-15 22:08:19,395 [main] INFO  org.apache.hadoop.mapred.ClientServiceDelegate - Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 2020-02-15 22:08:21,579 [JobControl] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-02-15 22:08:21,626 [JobControl] WARN  org.apache.hadoop.mapreduce.JobResourceUploader - No job jar file set.  User classes may not be found. See Job or Job#setJar(String).
# 2020-02-15 22:08:21,663 [JobControl] INFO  org.apache.hadoop.mapreduce.lib.input.FileInputFormat - Total input files to process : 1
# 2020-02-15 22:08:21,727 [JobControl] INFO  org.apache.hadoop.mapreduce.JobSubmitter - number of splits:1
# 2020-02-15 22:08:22,196 [JobControl] INFO  org.apache.hadoop.mapreduce.JobSubmitter - Submitting tokens for job: job_1581803984332_0003
# 2020-02-15 22:08:22,216 [JobControl] INFO  org.apache.hadoop.mapred.YARNRunner - Job jar is not present. Not adding any jar to the list of resources.
# 2020-02-15 22:08:22,308 [JobControl] INFO  org.apache.hadoop.yarn.client.api.impl.YarnClientImpl - Submitted application application_1581803984332_0003
# 2020-02-15 22:08:22,319 [JobControl] INFO  org.apache.hadoop.mapreduce.Job - The url to track the job: http://72a54844fdeb:8088/proxy/application_1581803984332_0003/
# 2020-02-15 22:09:07,773 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-02-15 22:09:07,835 [main] INFO  org.apache.hadoop.mapred.ClientServiceDelegate - Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 2020-02-15 22:09:08,147 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-02-15 22:09:08,169 [main] INFO  org.apache.hadoop.mapred.ClientServiceDelegate - Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 2020-02-15 22:09:08,322 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-02-15 22:09:08,347 [main] INFO  org.apache.hadoop.mapred.ClientServiceDelegate - Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 2020-02-15 22:09:08,886 [JobControl] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-02-15 22:09:08,927 [JobControl] WARN  org.apache.hadoop.mapreduce.JobResourceUploader - No job jar file set.  User classes may not be found. See Job or Job#setJar(String).
# 2020-02-15 22:09:08,966 [JobControl] INFO  org.apache.hadoop.mapreduce.lib.input.FileInputFormat - Total input files to process : 1
# 2020-02-15 22:09:09,844 [JobControl] INFO  org.apache.hadoop.mapreduce.JobSubmitter - number of splits:1
# 2020-02-15 22:09:09,914 [JobControl] INFO  org.apache.hadoop.mapreduce.JobSubmitter - Submitting tokens for job: job_1581803984332_0004
# 2020-02-15 22:09:09,922 [JobControl] INFO  org.apache.hadoop.mapred.YARNRunner - Job jar is not present. Not adding any jar to the list of resources.
# 2020-02-15 22:09:10,012 [JobControl] INFO  org.apache.hadoop.yarn.client.api.impl.YarnClientImpl - Submitted application application_1581803984332_0004
# 2020-02-15 22:09:10,020 [JobControl] INFO  org.apache.hadoop.mapreduce.Job - The url to track the job: http://72a54844fdeb:8088/proxy/application_1581803984332_0004/
# 2020-02-15 22:09:45,309 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-02-15 22:09:45,335 [main] INFO  org.apache.hadoop.mapred.ClientServiceDelegate - Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 2020-02-15 22:09:45,564 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-02-15 22:09:45,574 [main] INFO  org.apache.hadoop.mapred.ClientServiceDelegate - Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 2020-02-15 22:09:45,626 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-02-15 22:09:45,633 [main] INFO  org.apache.hadoop.mapred.ClientServiceDelegate - Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 2020-02-15 22:09:45,718 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-02-15 22:09:45,727 [main] INFO  org.apache.hadoop.mapred.ClientServiceDelegate - Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 2020-02-15 22:09:45,796 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-02-15 22:09:45,803 [main] INFO  org.apache.hadoop.mapred.ClientServiceDelegate - Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 2020-02-15 22:09:45,856 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-02-15 22:09:45,862 [main] INFO  org.apache.hadoop.mapred.ClientServiceDelegate - Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 2020-02-15 22:09:45,915 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-02-15 22:09:45,923 [main] INFO  org.apache.hadoop.mapred.ClientServiceDelegate - Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 2020-02-15 22:09:45,984 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-02-15 22:09:45,991 [main] INFO  org.apache.hadoop.mapred.ClientServiceDelegate - Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 2020-02-15 22:09:46,063 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-02-15 22:09:46,070 [main] INFO  org.apache.hadoop.mapred.ClientServiceDelegate - Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 2020-02-15 22:09:46,141 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-02-15 22:09:46,148 [main] INFO  org.apache.hadoop.mapred.ClientServiceDelegate - Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 2020-02-15 22:09:46,193 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-02-15 22:09:46,200 [main] INFO  org.apache.hadoop.mapred.ClientServiceDelegate - Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 2020-02-15 22:09:46,251 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-02-15 22:09:46,257 [main] INFO  org.apache.hadoop.mapred.ClientServiceDelegate - Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 2020-02-15 22:09:46,337 [main] INFO  org.apache.hadoop.mapreduce.lib.input.FileInputFormat - Total input files to process : 1
# (Boyer,BOYER,boyer)
# (Coffey,COFFEY,coffey)
# (Conway,CONWAY,conway)
# (Crane,CRANE,crane)
# (Diaz,DIAZ,diaz)
# (Estes,ESTES,estes)
# (Fry,FRY,fry)
# (Garrett,GARRETT,garrett)
# (Guy,GUY,guy)
# (Hamilton,HAMILTON,hamilton)
# (Holcomb,HOLCOMB,holcomb)
# (Jarvis,JARVIS,jarvis)
# (Kinney,KINNEY,kinney)
# (Klein,KLEIN,klein)
# (Knight,KNIGHT,knight)
# (Noel,NOEL,noel)
# (Sexton,SEXTON,sexton)
# (Silva,SILVA,silva)
#  --A = FOREACH u GENERATE $2, FLATTEN(STRSPLIT($2,''));
#  --B = FOREACH A GENERATE $0, COUNT(TOBAG($1..));
#  --C = ORDER B BY $0 DESC;
#  --D = ORDER C BY $1 DESC;
#  --E= LIMIT D 5;
#  --STORE A INTO 'output' USING PigStorage(',');
#  --u = LOAD 'data.csv' USING PigStorage(',');
#  --AS (f1:chararray, f2:BAG{t: TUPLE()}, f3:MAP[]);
#  --B = FOREACH A GENERATE $0, $1;
#  --grouped = GROUP B BY ($0, $1);
#  --D = FOREACH grouped GENERATE group, COUNT(B);
#  --USING PigStorage('\t')
# 'ddd', f3#'eee', f3#'fff',f3#'ggg',f3#'hhh',f3#'iii', f3#'jjj';#'ccc', f3#
#  --B = FOREACH A GENERATE $0, $1, COUNT(TOBAG($2..));
#  --C = ORDER B BY $0, $1, $2;
#  --A = LOAD "input" USING PigStorage(",") AS(f1:int,f2:chararray);;
#  --B = FOREACH A GENERATE f1, FLATTEN(STRSPLIT(f2,"_"));
#  --C = FOREACH B GENERATE $0,COUNT(TOBAG($1..));
#  --grouped = GROUP u BY $1;
#  --x = FOREACH u GENERATE COUNT(TOKENIZE($1));
#  --y = FOREACH u GENERATE $0, FLATTEN(TOKENIZE(REPLACE($1,'{', ' ')));
#  --grouped = GROUP x BY $0;
#  --keycount = FOREACH grouped GENERATE group, COUNT(x);

# %%
# %pig_quit
